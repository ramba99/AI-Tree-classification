# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.utils import to_categorical


# This code is to Load the dataset
data = pd.read_csv('Dataset.csv', encoding='ISO-8859-1')
print(data)  # Print the whole dataset

# This code define features and target
features = ['Length', 'Width', 'l/w', 'top angle', 'Length of the petiole']
target = 'Species'

# This code ensure 'top angle' is string, remove degree symbol, and convert to float.This is a recorrection of a mistake happened while making the dataset
data['top angle'] = data['top angle'].astype(str).str.replace('°', '').astype(float)

# This code is to extract features and target variables
X = data[features].values
y = data[target].values

#This code is to encode the target variable
target_label_encoder = LabelEncoder()
y = target_label_encoder.fit_transform(y)
y = to_categorical(y)

# This code is to scale the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# This code define a function to build the model
def build_model(input_dim, output_dim):
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(output_dim, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# This code Uses k-fold cross-validation to evaluate the model
kf = KFold(n_splits=5, shuffle=True, random_state=42)
all_accuracies = []

for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    model = build_model(input_dim=X.shape[1], output_dim=y.shape[1])
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), verbose=0)

    val_accuracy = history.history['val_accuracy'][-1]
    all_accuracies.append(val_accuracy)

average_accuracy = np.mean(all_accuracies)
print(f'Average Validation Accuracy is: {average_accuracy*100:.2f}%')

# With the help of this code we can train the final model.
model = build_model(input_dim=X.shape[1], output_dim=y.shape[1])
history = model.fit(X, y, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# This is the function to preprocess input data and make predictions
def predict_tree_species(input_features):
    # Convert input features to a dataframe for easier processing
    input_df = pd.DataFrame([input_features], columns=features)

    # Scale the features
    input_scaled = scaler.transform(input_df)

    # Make predictions
    prediction = model.predict(input_scaled)
    predicted_class = np.argmax(prediction, axis=1)

    # Convert the predicted class back to the original label
    predicted_species = target_label_encoder.inverse_transform(predicted_class)
    return predicted_species[0]

# This function helps to get valid user input
def get_user_input(mean_std_data):
    while True:
        try:
            user_length = float(input("Enter the Length of the leaf: "))
            user_width = float(input("Enter the Width of the leaf: "))
            user_top_angle = float(input("Enter the top angle of the leaf: "))
            user_length_of_petiole = float(input("Enter the Length of the petiole of the leaf: "))

            if user_length <= 0 or user_width <= 0:
                raise ValueError("Length and Width must be positive numbers.")
            if user_length <= user_width:
                raise ValueError("Length must be greater than Width.")

            user_l_w = user_length / user_width
            user_input = [user_length, user_width, user_l_w, user_top_angle, user_length_of_petiole]
            
            # This Checks whether user input is within the acceptable range
            for i, feature in enumerate(features):
                mean, std = mean_std_data[feature]
                if not (mean - 3 * std <= user_input[i] <= mean + 3 * std):
                    raise ValueError(f"The value for {feature} is not within the acceptable range based on the dataset.")
            
            return user_input
        except ValueError as e:
            print(f"Invalid input: {e}. Please try again.")

# This code Calculate mean and standard deviation for each feature
mean_std_data = {feature: (data[feature].mean(), data[feature].std()) for feature in features}

# This code is to get user input
user_input = get_user_input(mean_std_data)

# Finally Making the prediction based on user input
predicted_species = predict_tree_species(user_input)
print(f'The predicted species is: {predicted_species}')
# Out:
#       Species  Length  Width   l/w  top angle  Length of the petiole
# 0    Uguressa     7.4    3.7  2.00        110                    0.8
# 1   Weliwenna     8.2    3.7  2.21         80                    0.9
# 2      Veralu     7.5    3.9  1.92         80                    1.2
# 3    Uguressa     8.4    4.8  1.75        145                    0.8
# 4   Weliwenna     9.2    3.8  2.41         72                    1.0
# ..        ...     ...    ...   ...        ...                    ...
# 85     Veralu     7.6    4.2  1.80         78                    2.0
# 86   Uguressa     7.9    3.6  2.19        145                    0.7
# 87  Weliwenna     9.1    3.6  2.52         72                    0.9
# 88  Weliwenna     8.9    3.5  2.54         76                    1.0
# 89   Uguressa     8.1    4.5  1.80        141                    0.9
#
# [90 rows x 6 columns]
# Average Validation Accuracy is: 100.00%
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0201 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0246 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0259 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0282 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 9.7655e-04
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 9.3977e-04
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 9.0068e-04
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 8.6459e-04
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 1.0000 - val_loss: 8.2838e-04
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 7.9605e-04
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 7.6771e-04
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 7.4252e-04
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 7.1759e-04
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 6.9525e-04
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 1.0000 - val_loss: 6.7480e-04
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 6.5427e-04
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 6.3547e-04
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 6.1715e-04
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 5.9992e-04
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 5.8076e-04
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 5.6073e-04
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 5.4235e-04
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 5.2393e-04
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 1.0000 - val_loss: 5.0159e-04
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 4.7800e-04
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 4.5860e-04
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 4.4208e-04
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 4.2793e-04
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 4.1539e-04
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 4.0451e-04
# Enter the Length of the leaf: 2
# Enter the Width of the leaf: 4.5
# Enter the top angle of the leaf: 90
# Enter the Length of the petiole of the leaf: 1.1
# Invalid input: Length must be greater than Width.. Please try again.
# Enter the Length of the leaf: 6
# Enter the Width of the leaf: 4.5
# Enter the top angle of the leaf: 90
# Enter the Length of the petiole of the leaf: 1.1
# Invalid input: The value for Length is not within the acceptable range based on the dataset.. Please try again.
# Enter the Length of the leaf: 9
# Enter the Width of the leaf: 2.9
# Enter the top angle of the leaf: 90
# Enter the Length of the petiole of the leaf: 1
# Invalid input: The value for l/w is not within the acceptable range based on the dataset.. Please try again.
# Enter the Length of the leaf: 9
# Enter the Width of the leaf: 3.5
# Enter the top angle of the leaf: 10
# Enter the Length of the petiole of the leaf: 1
# Invalid input: The value for top angle is not within the acceptable range based on the dataset.. Please try again.
# Enter the Length of the leaf: 9
# Enter the Width of the leaf: 3.5
# Enter the top angle of the leaf: 30
# Enter the Length of the petiole of the leaf: 1
# C:\Users\asus_pc\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# The predicted species is: Weliwenna
